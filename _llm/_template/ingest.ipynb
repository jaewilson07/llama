# %%
import os
from pathlib import Path
from typing import List

from langchain_community.document_loaders import BSHTMLLoader

from langchain.chains.openai_functions import create_structured_output_chain
from langchain.text_splitter import TokenTextSplitter
from langchain_community.chat_models import ChatOpenAI
from langchain_community.document_loaders import TextLoader
from langchain_community.embeddings.openai import OpenAIEmbeddings
from langchain_community.graphs import Neo4jGraph
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.pydantic_v1 import BaseModel, Field
from neo4j.exceptions import ClientError

from domolibrary_extensions.utils import get_all_files_and_folders

# %%
base_folder_path = "../../scraper/SCRAPE"

file_ls = [
    file_name
    for file_name in get_all_files_and_folders(base_folder_path, "content.html")
    if "s_article_" in file_name
]
file_ls
# Out:
# ['../../scraper/SCRAPE/s_article_1500000572542/content.html',
#  '../../scraper/SCRAPE/s_article_360056669354/content.html',
#  '../../scraper/SCRAPE/s_article_360043427513/content.html',
#  '../../scraper/SCRAPE/s_article_360043431553/content.html',
#  '../../scraper/SCRAPE/s_article_1500003263261/content.html',
#  '../../scraper/SCRAPE/s_article_360042928494/content.html',
#  '../../scraper/SCRAPE/s_article_360042933854/content.html',
#  '../../scraper/SCRAPE/s_article_360042923674/content.html',
#  '../../scraper/SCRAPE/s_article_1500003956542/content.html',
#  '../../scraper/SCRAPE/s_article_360043436053/content.html',
#  '../../scraper/SCRAPE/s_article_360044876614/content.html',
#  '../../scraper/SCRAPE/s_article_360060598333/content.html',
#  '../../scraper/SCRAPE/s_article_360060507713/content.html',
#  '../../scraper/SCRAPE/s_article_360042930034/content.html',
#  '../../scraper/SCRAPE/s_article_9337403057943/content.html',
#  '../../scraper/SCRAPE/s_article_360042927114/content.html',
#  '../../scraper/SCRAPE/s_article_360043434613/content.html',
#  '../../scraper/SCRAPE/s_article_4420450699415/content.html',
#  '../../scraper/SCRAPE/s_article_360047553253/content.html',
#  '../../scraper/SCRAPE/s_article_360043430973/content.html',
#  '../../scraper/SCRAPE/s_article_360045163773/content.html',
#  '../../scraper/SCRAPE/s_article_4405156517527/content.html',
#  '../../scraper/SCRAPE/s_article_4406022964375/content.html',
#  '../../scraper/SCRAPE/s_article_360042934194/content.html',
#  '../../scraper/SCRAPE/s_article_1500009366622/content.html',
#  '../../scraper/SCRAPE/s_article_360057013414/content.html',
#  '../../scraper/SCRAPE/s_article_360057028494/content.html',
#  '../../scraper/SCRAPE/s_article_360042929154/content.html',
#  '../../scraper/SCRAPE/s_article_360042922874/content.html',
#  '../../scraper/SCRAPE/s_article_360042926134/content.html',
#  '../../scraper/SCRAPE/s_article_7964629384087/content.html',
#  '../../scraper/SCRAPE/s_article_360043433753/content.html',
#  '../../scraper/SCRAPE/s_article_000005342/content.html',
#  '../../scraper/SCRAPE/s_article_360061648033/content.html',
#  '../../scraper/SCRAPE/s_article_360042923234/content.html',
#  '../../scraper/SCRAPE/s_article_360043439893/content.html',
#  '../../scraper/SCRAPE/s_article_000005174/content.html',
#  '../../scraper/SCRAPE/s_article_360043438513/content.html',
#  '../../scraper/SCRAPE/s_article_360042926694/content.html',
#  '../../scraper/SCRAPE/s_article_360058892493/content.html',
#  '../../scraper/SCRAPE/s_article_360042933474/content.html',
#  '../../scraper/SCRAPE/s_article_360043433253/content.html',
#  '../../scraper/SCRAPE/s_article_1500000214222/content.html',
#  '../../scraper/SCRAPE/s_article_360058792094/content.html',
#  '../../scraper/SCRAPE/s_article_360042922954/content.html',
#  '../../scraper/SCRAPE/s_article_360042930114/content.html',
#  '../../scraper/SCRAPE/s_article_360058891393/content.html',
#  '../../scraper/SCRAPE/s_article_360042934974/content.html',
#  '../../scraper/SCRAPE/s_article_360042925634/content.html',
#  '../../scraper/SCRAPE/s_article_1500000406641/content.html',
#  '../../scraper/SCRAPE/s_article_360042928634/content.html',
#  '../../scraper/SCRAPE/s_article_360042931614/content.html',
#  '../../scraper/SCRAPE/s_article_36004740075/content.html',
#  '../../scraper/SCRAPE/s_article_360042932434/content.html',
#  '../../scraper/SCRAPE/s_article_360042925774/content.html',
#  '../../scraper/SCRAPE/s_article_360042929694/content.html',
#  '../../scraper/SCRAPE/s_article_360043439733/content.html',
#  '../../scraper/SCRAPE/s_article_360058716313/content.html',
#  '../../scraper/SCRAPE/s_article_360042929434/content.html',
#  '../../scraper/SCRAPE/s_article_360043433693/content.html',
#  '../../scraper/SCRAPE/s_article_360043434913/content.html',
#  '../../scraper/SCRAPE/s_article_360043431053/content.html',
#  '../../scraper/SCRAPE/s_article_9301034807575/content.html',
#  '../../scraper/SCRAPE/s_article_360043428793/content.html',
#  '../../scraper/SCRAPE/s_article_360042924774/content.html',
#  '../../scraper/SCRAPE/s_article_360043435313/content.html',
#  '../../scraper/SCRAPE/s_article_1500000196942/content.html',
#  '../../scraper/SCRAPE/s_article_360042931454/content.html',
#  '../../scraper/SCRAPE/s_article_360042926894/content.html',
#  '../../scraper/SCRAPE/s_article_4407033316887/content.html',
#  '../../scraper/SCRAPE/s_article_360042925814/content.html',
#  '../../scraper/SCRAPE/s_article_360042929474/content.html',
#  '../../scraper/SCRAPE/s_article_360043431473/content.html',
#  '../../scraper/SCRAPE/s_article_360043429293/content.html',
#  '../../scraper/SCRAPE/s_article_360042925414/content.html',
#  '../../scraper/SCRAPE/s_article_360042927874/content.html',
#  '../../scraper/SCRAPE/s_article_360042931294/content.html']

# %%
def load_file(file_path):
    if not os.path.exists(file_path):
        raise FileNotFoundError(file_path)

    loader = BSHTMLLoader(file_path)
    data = loader.load()
    return data

# %%
test_file = file_ls[0]

load_file(test_file)
# Out:
# [Document(page_content='Retail Express ConnectorOct 24, 2022•KnowledgeInformationTitleRetail Express ConnectorArticle BodyIntro\nRetail Express is a cloud-based POS, inventory, and eCommerce software that provides inventory-based Australian and NZ retailers with a central platform. It helps to manage sales and services, inventory and logistics, marketing, and loyalty, business intelligence practices, and much more across multiple online stores. As a cloud solution, Retail Express gives you the flexibility to manage your business anytime, anywhere, via any internet-enabled devices. Reports and dashboards give users valuable insight into business performance. The Retail Express Web Store API and the IPS API are the web services that allow e-commerce web sites to communicate with Retail Express point of sale and stock control software. This enables the synchronization of products, pricing, purchase orders, customers, internal transfers, and other business-specific information to help reduce the amount of administration required to maintain an online e-commerce website and an IPS. Use Domo\'s Retail Express connector to retrieve the web store and inventory planning systems data.\nThe Retail Express Connector is a "Cloud App" Connector, meaning it retrieves data stored in the cloud. In the Data Center, you can access the Connector page for this and other Cloud App Connectors by clicking Cloud App in the toolbar at the top of the window.\nYou connect to your Retail Express account in the Data Center. This topic discusses the fields and menus that are specific to the Retail Express\xa0Connector user interface. General information for adding DataSets, setting update schedules, and editing DataSet information is discussed in Adding a DataSet Using a Data Connector.\nPrimary Use CasesThis Connector lets you retrieve data about sales and services, inventory and logistics, marketing, and business intelligence practices.\nPrimary Metrics\nCustomer DataCustomer DetailsOrder DetailsPurchase Order DetailsStaff DetailsSupplier DetailsOutlet\nPrimary Company Roles\nInventory ManagementSales and ServicesLogisticsMarketingMarketing Analytics\nAverage Implementation TimeLess than an hour.Ease of Use (on a 1-to-10 scale with 1 being easiest)3\nPrerequisites\nTo connect to your Retail Express account and create a DataSet, you must have the following:\nYour domain name of the web service accountYour unique client code of retail express accountThe username and password associated with your Retails Express account\nConnecting to Your Retails Express\xa0Account\nThis section enumerates the options in the Credentials and Details panes in the Retails Express Connector page. The components of the other panes in this page, Scheduling and Name & Describe Your DataSet, are universal across most connector types and are discussed in greater length in Adding a DataSet Using a Data Connector.\nCredentials Pane\nThis pane contains fields for entering credentials to connect to your Retails Express\xa0account. The following table describes what is needed for each field:\n\xa0\n\nField\n\nDescription\n\nDomain\n\nEnter your domain name of the web service account.\n\nClient ID\n\nEnter your unique client code of retail express account.\n\nUsername\n\nEnter the username associated with your Retail Express account.\n\nPassword\n\nEnter the password associated with your Retail Express account.\n\nOnce you have entered valid Retails Express\xa0credentials, you can use the same account any time you go to create a new Retails Express DataSet. You can manage Connector accounts in the Accounts tab in the Data Center. For more information about this tab, see Managing User Accounts for Connectors.\nDetails Pane\nThis pane contains a primary Reports menu, along with various other menus which may or may not appear depending on the report type you select.\n\nMenu\n\nDescription\n\nReport\n\nSelect the Retail Express\xa0report you want to run. The following reports are available:\n ...

# %%
txt_path = Path(__file__).parent / "dune.txt"

graph = Neo4jGraph()

# Embeddings & LLM models
embeddings = OpenAIEmbeddings()
embedding_dimension = 1536
llm = ChatOpenAI(temperature=0)

# Load the text file
loader = TextLoader(str(txt_path))
documents = loader.load()

# Ingest Parent-Child node pairs
parent_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
child_splitter = TokenTextSplitter(chunk_size=100, chunk_overlap=24)
parent_documents = parent_splitter.split_documents(documents)

for i, parent in enumerate(parent_documents):
    child_documents = child_splitter.split_documents([parent])
    params = {
        "parent_text": parent.page_content,
        "parent_id": i,
        "parent_embedding": embeddings.embed_query(parent.page_content),
        "children": [
            {
                "text": c.page_content,
                "id": f"{i}-{ic}",
                "embedding": embeddings.embed_query(c.page_content),
            }
            for ic, c in enumerate(child_documents)
        ],
    }
    # Ingest data
    graph.query(
        """
    MERGE (p:Parent {id: $parent_id})
    SET p.text = $parent_text
    WITH p
    CALL db.create.setVectorProperty(p, 'embedding', $parent_embedding)
    YIELD node
    WITH p 
    UNWIND $children AS child
    MERGE (c:Child {id: child.id})
    SET c.text = child.text
    MERGE (c)<-[:HAS_CHILD]-(p)
    WITH c, child
    CALL db.create.setVectorProperty(c, 'embedding', child.embedding)
    YIELD node
    RETURN count(*)
    """,
        params,
    )
    # Create vector index for child
    try:
        graph.query(
            "CALL db.index.vector.createNodeIndex('parent_document', "
            "'Child', 'embedding', $dimension, 'cosine')",
            {"dimension": embedding_dimension},
        )
    except ClientError:  # already exists
        pass
    # Create vector index for parents
    try:
        graph.query(
            "CALL db.index.vector.createNodeIndex('typical_rag', "
            "'Parent', 'embedding', $dimension, 'cosine')",
            {"dimension": embedding_dimension},
        )
    except ClientError:  # already exists
        pass
# Ingest hypothethical questions


class Questions(BaseModel):
    """Generating hypothetical questions about text."""

    questions: List[str] = Field(
        ...,
        description=(
            "Generated hypothetical questions based on " "the information from the text"
        ),
    )


questions_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "You are generating hypothetical questions based on the information "
                "found in the text. Make sure to provide full context in the generated "
                "questions."
            ),
        ),
        (
            "human",
            (
                "Use the given format to generate hypothetical questions from the "
                "following input: {input}"
            ),
        ),
    ]
)

question_chain = create_structured_output_chain(Questions, llm, questions_prompt)

for i, parent in enumerate(parent_documents):
    questions = question_chain.run(parent.page_content).questions
    params = {
        "parent_id": i,
        "questions": [
            {"text": q, "id": f"{i}-{iq}", "embedding": embeddings.embed_query(q)}
            for iq, q in enumerate(questions)
            if q
        ],
    }
    graph.query(
        """
    MERGE (p:Parent {id: $parent_id})
    WITH p
    UNWIND $questions AS question
    CREATE (q:Question {id: question.id})
    SET q.text = question.text
    MERGE (q)<-[:HAS_QUESTION]-(p)
    WITH q, question
    CALL db.create.setVectorProperty(q, 'embedding', question.embedding)
    YIELD node
    RETURN count(*)
    """,
        params,
    )
    # Create vector index
    try:
        graph.query(
            "CALL db.index.vector.createNodeIndex('hypothetical_questions', "
            "'Question', 'embedding', $dimension, 'cosine')",
            {"dimension": embedding_dimension},
        )
    except ClientError:  # already exists
        pass

# Ingest summaries

summary_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            (
                "You are generating concise and accurate summaries based on the "
                "information found in the text."
            ),
        ),
        (
            "human",
            ("Generate a summary of the following input: {question}\n" "Summary:"),
        ),
    ]
)

summary_chain = summary_prompt | llm

for i, parent in enumerate(parent_documents):
    summary = summary_chain.invoke({"question": parent.page_content}).content
    params = {
        "parent_id": i,
        "summary": summary,
        "embedding": embeddings.embed_query(summary),
    }
    graph.query(
        """
    MERGE (p:Parent {id: $parent_id})
    MERGE (p)-[:HAS_SUMMARY]->(s:Summary)
    SET s.text = $summary
    WITH s
    CALL db.create.setVectorProperty(s, 'embedding', $embedding)
    YIELD node
    RETURN count(*)
    """,
        params,
    )
    # Create vector index
    try:
        graph.query(
            "CALL db.index.vector.createNodeIndex('summary', "
            "'Summary', 'embedding', $dimension, 'cosine')",
            {"dimension": embedding_dimension},
        )
    except ClientError:  # already exists
        pass
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 txt_path = Path(__file__).parent / "dune.txt"
#       3 graph = Neo4jGraph()
#       5 # Embeddings & LLM models
#
# NameError: name '__file__' is not defined
